# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
id = "STUID"
df = pd.read_csv('/content/drive/MyDrive/PoseToCode - Top Level Folder/RealWorldStudyData/Survey Results/Code.org_PostSurvey.csv')
df_p2c_survey = pd.read_csv('/content/drive/MyDrive/PoseToCode - Top Level Folder/RealWorldStudyData/Survey Results/P2C_PostSurvey.csv', usecols=[id])
df_final_survey = pd.read_csv('/content/drive/MyDrive/PoseToCode - Top Level Folder/RealWorldStudyData/Survey Results/FinalPostSurvey.csv', usecols=[id])

# %%
participants_list_final = df_final_survey[id].tolist();
participants_list_p2c = df_p2c_survey[id].tolist();

df = df[df[id].isin(participants_list_final)]
df = df[df[id].isin(participants_list_p2c)]

print(df)
# Out:
#                                             StartDate  ...                 FIRAC
# 0                                          Start Date  ...                 FIRAC
# 1   {"ImportId":"startDate","timeZone":"America/De...  ...  {"ImportId":"FIRAC"}
# 2                                 2021-12-07 10:18:36  ...                     1
# 3                                 2021-12-07 10:18:29  ...                     1
# 5                                 2021-12-07 10:19:23  ...                     1
# 8                                 2021-12-07 10:22:15  ...                     1
# 9                                 2021-12-07 10:21:57  ...                     1
# 11                                2021-12-07 10:33:40  ...                     0
# 13                                2021-12-07 10:35:06  ...                     0
# 15                                2021-12-07 10:39:22  ...                     0
# 16                                2021-12-07 10:41:46  ...                     0
# ...

# %%
df = df.drop([0, 1])
print(df)
# Out:
#               StartDate  ... FIRAC
# 2   2021-12-07 10:18:36  ...     1
# 3   2021-12-07 10:18:29  ...     1
# 5   2021-12-07 10:19:23  ...     1
# 8   2021-12-07 10:22:15  ...     1
# 9   2021-12-07 10:21:57  ...     1
# 11  2021-12-07 10:33:40  ...     0
# 13  2021-12-07 10:35:06  ...     0
# 15  2021-12-07 10:39:22  ...     0
# 16  2021-12-07 10:41:46  ...     0
# 17  2021-12-07 10:40:54  ...     0
#
# [10 rows x 32 columns]

# %%
df.to_csv ('/content/drive/MyDrive/PoseToCode - Top Level Folder/DataAnalysis/export_codeorg_cleaned.csv', index = False, header=True)
