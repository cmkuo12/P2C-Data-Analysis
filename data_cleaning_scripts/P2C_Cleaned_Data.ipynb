# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
id = "STUID"
df_p2c_survey = pd.read_csv('/content/drive/MyDrive/PoseToCode - Top Level Folder/RealWorldStudyData/Survey Results/P2C_PostSurvey.csv')
df_codeorg_survey = pd.read_csv('/content/drive/MyDrive/PoseToCode - Top Level Folder/RealWorldStudyData/Survey Results/Code.org_PostSurvey.csv', usecols=[id])
df_final_survey = pd.read_csv('/content/drive/MyDrive/PoseToCode - Top Level Folder/RealWorldStudyData/Survey Results/FinalPostSurvey.csv', usecols=[id])

# %%
# use only participants that also completed final survey (meaning that they finished both activities)
# for some reason none of the response IDs matched?? so used IP Address
participants_list_final = df_final_survey[id].tolist();
participants_list_codeorg = df_codeorg_survey[id].tolist();

df_p2c_survey = df_p2c_survey[df_p2c_survey[id].isin(participants_list_final)]
df_p2c_survey = df_p2c_survey[df_p2c_survey[id].isin(participants_list_codeorg)]

print(df_p2c_survey)
# Out:
#                                             StartDate  ...                 FIRAC
# 0                                          Start Date  ...                 FIRAC
# 1   {"ImportId":"startDate","timeZone":"America/De...  ...  {"ImportId":"FIRAC"}
# 2                                 2021-12-07 10:19:01  ...                     0
# 3                                 2021-12-07 10:22:15  ...                     0
# 4                                 2021-12-07 10:22:12  ...                     0
# 6                                 2021-12-07 10:20:53  ...                     0
# 7                                 2021-12-07 10:24:03  ...                     0
# 8                                 2021-12-07 10:31:59  ...                     1
# 9                                 2021-12-07 10:31:15  ...                     1
# 10                                2021-12-07 10:33:23  ...                     1
# 13                                2021-12-07 10:38:56  ...                     1
# ...

# %%
df_p2c_survey = df_p2c_survey.drop([0, 1])
print(df_p2c_survey)
# Out:
#               StartDate  ... FIRAC
# 2   2021-12-07 10:19:01  ...     0
# 3   2021-12-07 10:22:15  ...     0
# 4   2021-12-07 10:22:12  ...     0
# 6   2021-12-07 10:20:53  ...     0
# 7   2021-12-07 10:24:03  ...     0
# 8   2021-12-07 10:31:59  ...     1
# 9   2021-12-07 10:31:15  ...     1
# 10  2021-12-07 10:33:23  ...     1
# 13  2021-12-07 10:38:56  ...     1
# 15  2021-12-07 10:38:28  ...     1
#
# [10 rows x 34 columns]

# %%
df_p2c_survey.to_csv ('/content/drive/MyDrive/PoseToCode - Top Level Folder/DataAnalysis/export_p2c_cleaned.csv', index = False, header=True)
