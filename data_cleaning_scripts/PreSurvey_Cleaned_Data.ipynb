# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
id = "STUID"
df = pd.read_csv('/content/drive/MyDrive/PoseToCode - Top Level Folder/RealWorldStudyData/Survey Results/P2CPreSurvey_December 7, 2021_11.20.csv')
df_final_survey = pd.read_csv('/content/drive/MyDrive/PoseToCode - Top Level Folder/DataAnalysis/export_final_cleaned.csv', usecols=[id])

# %%
participants_list = df_final_survey[id].tolist();

df = df[df[id].isin(participants_list)]

print(df)
# Out:
#               StartDate  ... FIRAC
# 2   2021-12-07 10:04:39  ...     1
# 3   2021-12-07 10:04:45  ...     1
# 5   2021-12-07 10:04:46  ...     0
# 9   2021-12-07 10:04:54  ...     1
# 10  2021-12-07 10:05:00  ...     0
# 12  2021-12-07 10:04:39  ...     0
# 13  2021-12-07 10:05:09  ...     1
# 15  2021-12-07 10:04:52  ...     0
# 17  2021-12-07 10:04:50  ...     1
# 19  2021-12-07 10:04:40  ...     0
#
# [10 rows x 31 columns]

# %%
df.to_csv ('/content/drive/MyDrive/PoseToCode - Top Level Folder/DataAnalysis/export_presurvey_cleaned.csv', index = False, header=True)
