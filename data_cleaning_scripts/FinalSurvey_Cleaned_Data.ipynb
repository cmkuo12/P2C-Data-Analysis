# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
id = "STUID"
df_p2c_survey = pd.read_csv('/content/drive/MyDrive/PoseToCode - Top Level Folder/RealWorldStudyData/Survey Results/P2C_PostSurvey.csv', usecols=[id])
df_codeorg_survey = pd.read_csv('/content/drive/MyDrive/PoseToCode - Top Level Folder/RealWorldStudyData/Survey Results/Code.org_PostSurvey.csv', usecols=[id])
df_final_survey = pd.read_csv('/content/drive/MyDrive/PoseToCode - Top Level Folder/RealWorldStudyData/Survey Results/FinalPostSurvey.csv')

# %%
# use only participants that also completed final survey (meaning that they finished both activities)
# for some reason none of the response IDs matched?? so used IP Address
participants_list_p2c = df_p2c_survey[id].tolist();
participants_list_codeorg = df_codeorg_survey[id].tolist();

df_final_survey = df_final_survey[df_final_survey[id].isin(participants_list_p2c)]
df_final_survey = df_final_survey[df_final_survey[id].isin(participants_list_codeorg)]

print(df_final_survey)
# Out:
#                                             StartDate  ...                 FIRAC
# 0                                          Start Date  ...                 FIRAC
# 1   {"ImportId":"startDate","timeZone":"America/De...  ...  {"ImportId":"FIRAC"}
# 3                                 2021-12-07 10:36:34  ...                     1
# 4                                 2021-12-07 10:36:50  ...                     0
# 5                                 2021-12-07 10:37:50  ...                     0
# 6                                 2021-12-07 10:38:17  ...                     1
# 8                                 2021-12-07 10:39:09  ...                     1
# 9                                 2021-12-07 10:42:15  ...                     0
# 10                                2021-12-07 10:46:47  ...                     0
# 11                                2021-12-07 10:44:23  ...                     0
# 12                                2021-12-07 10:45:51  ...                     1
# ...

# %%
df_final_survey = df_final_survey.drop([0, 1])
print(df_final_survey)
# Out:
#               StartDate  ... FIRAC
# 3   2021-12-07 10:36:34  ...     1
# 4   2021-12-07 10:36:50  ...     0
# 5   2021-12-07 10:37:50  ...     0
# 6   2021-12-07 10:38:17  ...     1
# 8   2021-12-07 10:39:09  ...     1
# 9   2021-12-07 10:42:15  ...     0
# 10  2021-12-07 10:46:47  ...     0
# 11  2021-12-07 10:44:23  ...     0
# 12  2021-12-07 10:45:51  ...     1
# 15  2021-12-07 10:50:06  ...     1
#
# [10 rows x 21 columns]

# %%
df_final_survey.to_csv ('/content/drive/MyDrive/PoseToCode - Top Level Folder/DataAnalysis/export_final_cleaned.csv', index = False, header=True)
